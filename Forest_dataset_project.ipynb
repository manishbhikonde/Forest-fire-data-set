# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns
from warnings import filterwarnings
filterwarnings('ignore')

# %%
! pip install matplotlib

# %%
! pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 24.2 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df=pd.read_csv(r"C:\Projects\forest fire\Algerian_forest_fires_dataset_UPDATE (3).csv",header=1)

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 0    0.5   not fire
# 1    0.4   not fire
# ...

# %%
df.shape
# Out:
# (246, 14)

# %%
df.info
# Out:
# <bound method DataFrame.info of     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 0    0.5   not fire
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
df.loc [:122,'Region']=1
df.loc [122:,'Region']=2
df[['Region']]=df[['Region']].astype(int)

# %%
df.head
# Out:
# <bound method NDFrame.head of     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 239  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 240  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 241  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 242  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 243  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    Region
# ...

# %%
df=df.dropna().reset_index(drop=True)
df.shape
# Out:
# (244, 15)

# %%
df.tail()
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 239  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 240  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 241  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 242  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 243  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    Region
# 239  6.5       fire          2
# 240    0   not fire          2
# 241  0.2   not fire          2
# 242  0.7   not fire          2
# 243  0.5  not fire           2

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire          1
# 1  not fire          1
# 2  not fire          1
# 3  not fire          1
# 4  not fire          1

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
df.iloc[[122]]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI  \
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#      FWI  Classes    Region
# 122  FWI  Classes         2

# %%
# Null and other unwanted rows and 

df=df.drop(122).reset_index(drop=True)

# %%
df.shape
# Out:
# (243, 15)

# %%
df[['day', 'month', 'year', 'Temperature', ' RH', ' Ws']]=df[['day', 'month', 'year', 'Temperature', ' RH', ' Ws']].astype(int)

# %%
df
# Out:
#      day  month  year  Temperature   RH   Ws Rain   FFMC  DMC    DC  ISI  \
# 0      1      6  2012           29   57   18     0  65.7  3.4   7.6  1.3
# 1      2      6  2012           29   61   13   1.3  64.4  4.1   7.6    1
# 2      3      6  2012           26   82   22  13.1  47.1  2.5   7.1  0.3
# 3      4      6  2012           25   89   13   2.5  28.6  1.3   6.9    0
# 4      5      6  2012           27   77   16     0  64.8    3  14.2  1.2
# ..   ...    ...   ...          ...  ...  ...   ...   ...  ...   ...  ...
# 238   26      9  2012           30   65   14     0  85.4   16  44.5  4.5
# 239   27      9  2012           28   87   15   4.4  41.1  6.5     8  0.1
# 240   28      9  2012           27   87   29   0.5  45.9  3.5   7.9  0.4
# 241   29      9  2012           24   54   18   0.1  79.7  4.3  15.2  1.7
# 242   30      9  2012           24   64   15   0.2  67.3  3.8  16.5  1.2
#
#       BUI  FWI     Classes    Region
# 0     3.4  0.5   not fire          1
# ...

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %%
df.columns=df.columns.str.strip()
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
objects = [features for features in df.columns if df[features].dtype == 'O']

# %%
#for i in objects :
#    if i == "Classes" :
#       df[i]=df[i].astype(float)

# %%
objects
# Out:
# ['Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes']

# %%
for i in objects:
    if i == "Classes":
        df[i] = df[i].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 3
#       1 for i in objects:
#       2     if i == "Classes":
# ----> 3         df[i] = df[i].astype(float)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df.Classes.value_counts()
# Out:
# Classes
# fire        137
# not fire    106
# Name: count, dtype: int64

# %%
df.Classes=df.Classes.str.strip()

# %%
df.Classes.value_counts()
# Out:
# Classes
# fire        137
# not fire    106
# Name: count, dtype: int64

# %%
df[:122]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0      1      6  2012           29  57  18     0  65.7  3.4   7.6  1.3  3.4
# 1      2      6  2012           29  61  13   1.3  64.4  4.1   7.6    1  3.9
# 2      3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3      4      6  2012           25  89  13   2.5  28.6  1.3   6.9    0  1.7
# 4      5      6  2012           27  77  16     0  64.8    3  14.2  1.2  3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...  ...   ...  ...  ...
# 117   26      9  2012           31  54  11     0    82    6  16.3  2.5  6.2
# 118   27      9  2012           31  66  11     0  85.7  8.3  24.9    4    9
# 119   28      9  2012           32  47  14   0.7  77.5  7.1   8.8  1.8  6.8
# 120   29      9  2012           26  80  16   1.8  47.4  2.9   7.7  0.3    3
# 121   30      9  2012           25  78  14   1.4    45  1.9   7.5  0.2  2.4
#
#      FWI   Classes  Region
# 0    0.5  not fire       1
# ...

# %%
df[122:]
# Out:
#      day  month  year  Temperature  RH  Ws Rain  FFMC  DMC    DC  ISI   BUI  \
# 122    1      6  2012           32  71  12  0.7  57.1  2.5   8.2  0.6   2.8
# 123    2      6  2012           30  73  13    4  55.7  2.7   7.8  0.6   2.9
# 124    3      6  2012           29  80  14    2  48.7  2.2   7.6  0.3   2.6
# 125    4      6  2012           30  64  14    0  79.4  5.2  15.4  2.2   5.6
# 126    5      6  2012           32  60  14  0.2  77.1    6  17.6  1.8   6.5
# ..   ...    ...   ...          ...  ..  ..  ...   ...  ...   ...  ...   ...
# 238   26      9  2012           30  65  14    0  85.4   16  44.5  4.5  16.9
# 239   27      9  2012           28  87  15  4.4  41.1  6.5     8  0.1   6.2
# 240   28      9  2012           27  87  29  0.5  45.9  3.5   7.9  0.4   3.4
# 241   29      9  2012           24  54  18  0.1  79.7  4.3  15.2  1.7   5.1
# 242   30      9  2012           24  64  15  0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI   Classes  Region
# 122  0.2  not fire       2
# ...

# %%
df.to_csv("clean_dataset_of_forest.csv",index=False)

# %% [markdown]
# EDA

# %%
df=pd.read_csv("clean_dataset_of_forest.csv")

# %%
df
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 238   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 239   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 240   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 241   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 242   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI   Classes  Region
# ...

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI   Classes  Region
# 0  0.5  not fire       1
# 1  0.4  not fire       1
# 2  0.1  not fire       1
# 3  0.0  not fire       1
# 4  0.5  not fire       1

# %%
df.info
# Out:
# <bound method DataFrame.info of      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 238   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 239   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 240   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 241   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 242   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
# ...

# %%
#Dropping Yera features

df2=df.drop(['day','month','year'],axis=1)

# %%
df2.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI   Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire       1
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire       1
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire       1
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire       1
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire       1

# %%
df2.Classes.value_counts()
# Out:
# Classes
# fire        137
# not fire    106
# Name: count, dtype: int64

# %%
df2['Classes']=np.where(df2['Classes']=='not fire',0,1)

# %%
df2
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5        0
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4        0
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1        0
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0        0
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5        0
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...  ...      ...
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0        0
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      Region
# 0         1
# 1         1
# 2         1
# 3         1
# ...

# %%
# Plot desn plot

# plt.style.use('seaborn')
df2.hist(bins=50,figsize=(20,15))
plt.show()

# %%
percentage=df.Classes.value_counts(normalize=True)*100
percentage
# Out:
# Classes
# fire        56.378601
# not fire    43.621399
# Name: proportion, dtype: float64

# %%
classeslabels=["FIRE", 'NOT FIRE']
plt.figure(figsize=(12,7))
plt.pie(percentage,labels=classeslabels,autopct='%1.1f%%')
plt.title('Pie Chart of Classes',fontsize=10)
plt.show()

# %%
ax=sns.boxplot(df['FWI'],color='orange')

# %%
dftemp=df.loc[df['Region']==1]

# %%
dftemp
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1      2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2      3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3      4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4      5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...  ...   ...  ...  ...
# 117   26      9  2012           31  54  11   0.0  82.0  6.0  16.3  2.5  6.2
# 118   27      9  2012           31  66  11   0.0  85.7  8.3  24.9  4.0  9.0
# 119   28      9  2012           32  47  14   0.7  77.5  7.1   8.8  1.8  6.8
# 120   29      9  2012           26  80  16   1.8  47.4  2.9   7.7  0.3  3.0
# 121   30      9  2012           25  78  14   1.4  45.0  1.9   7.5  0.2  2.4
#
#      FWI   Classes  Region
# 0    0.5  not fire       1
# ...

# %%
dftemp=df.loc[df['Region']==2]
dftemp
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 122    1      6  2012           32  71  12   0.7  57.1   2.5   8.2  0.6   2.8
# 123    2      6  2012           30  73  13   4.0  55.7   2.7   7.8  0.6   2.9
# 124    3      6  2012           29  80  14   2.0  48.7   2.2   7.6  0.3   2.6
# 125    4      6  2012           30  64  14   0.0  79.4   5.2  15.4  2.2   5.6
# 126    5      6  2012           32  60  14   0.2  77.1   6.0  17.6  1.8   6.5
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 238   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 239   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 240   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 241   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 242   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI   Classes  Region
# ...

# %%
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x='month', hue='Classes', data=df, ec='black', palette='Set2')
plt.title('Fire Analysis Month wise for Region', fontsize=18, weight='bold')
plt.ylabel('Count', weight='bold')
plt.xlabel('Month', weight='bold')
plt.legend(loc='upper right')
plt.xticks(np.arange(4), ['June', 'July', 'August', 'September'])
plt.grid(alpha=0.5, axis='y')
plt.show()

# %%
def barchart (feature,xlable):
    plt.figure(figsize=[14,8])
    by_feature=df2.groupby([feature],as_index=False)['Classes'].sum()
    ax=sns.barplot(x=feature,y="Classes",data=by_feature[[feature,'Classes']],estimator=sum)
    ax.set(xlable=xlable,ylabel='Fire Count')

# %%
barchart('Temperature','Temperature Max in Celsius degrees')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 barchart('Temperature','Temperature Max in Celsius degrees')
#
# Cell In[57], line 5, in barchart(feature, xlable)
#       3 by_feature=df2.groupby([feature],as_index=False)['Classes'].sum()
#       4 ax=sns.barplot(x=feature,y="Classes",data=by_feature[[feature,'Classes']],estimator=sum)
# ----> 5 ax.set(xlable=xlable,ylabel='Fire Count')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\artist.py:147, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     139 if not hasattr(cls.set, '_autogenerated_signature'):
#     140     # Don't overwrite cls.set if the subclass or one of its parents
#     141     # has defined a set method set itself.
#     142     # If there was no explicit definition, cls.set is inherited from
# ...

# %%
barchart('Rain','rain in mm')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 barchart('Rain','rain in mm')
#
# Cell In[57], line 5, in barchart(feature, xlable)
#       3 by_feature=df2.groupby([feature],as_index=False)['Classes'].sum()
#       4 ax=sns.barplot(x=feature,y="Classes",data=by_feature[[feature,'Classes']],estimator=sum)
# ----> 5 ax.set(xlable=xlable,ylabel='Fire Count')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\artist.py:147, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     139 if not hasattr(cls.set, '_autogenerated_signature'):
#     140     # Don't overwrite cls.set if the subclass or one of its parents
#     141     # has defined a set method set itself.
#     142     # If there was no explicit definition, cls.set is inherited from
#     143     # the hierarchy of auto-generated set methods, which hold the
# ...

# %%
dftemp=df.drop(['Classes','Region'],axis=1)
fig=plt.figure(figsize=(12,6))
ax=dftemp.boxplot()
ax.set_title("Boxplot of Given Dataset")
plt.show()

# %%
dftemp=df2.drop(['Classes','Region'],axis=1)
fig=plt.figure(figsize=(12,6))
ax=dftemp.boxplot()
ax.set_title("Boxplot of Given Dataset")
plt.show()

# %%
dftemp=df2.drop(['Region', 'Temperature', 'Rain', 'Ws' , 'RH'],axis=1)
for feature in dftemp: 
    sns.histplot(data=dftemp,x=feature,hue='Classes')
    plt.legend(labels=['Fire','Not Fire'])
    plt.title(feature)
    plt.show()
